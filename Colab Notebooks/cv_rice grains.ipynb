# %%
# !git clone https://github.com/WongKinYiu/yolov7
# %cd yolov7
# !pip install -r requirements.txt

# %%
# %cd /content/yolov7
# !wget "https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7.pt"

# %%
# !python train.py --batch 4  --cfg cfg/training/yolov7.yaml --epochs 150 --data data/coco.yaml --weights 'yolov7.pt' --device 0

# %%
# !python detect.py --source "/content/yolov7/dataset/test" --weights "/content/yolov7/runs/train/exp/weights/best.pt"
